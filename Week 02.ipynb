# %% [markdown]
# # Excercises (DIY) - Part 1

# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Surface\\Desktop\\City University\\Principles of Data Science\\Week 02'

# %%
passengerData = pd.read_csv("passengerData.csv")

# %%
passengerData
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
ticketprices = pd.read_excel("ticketPrices.xlsx")

# %%
ticketprices
# Out:
#    TicketType  Fare
# 0           1    33
# 1           2    56
# 2           3    77
# 3           4    22
# 4           5    14
# 5           6    66
# 6           7    87
# 7           8    36

# %%
merging_passenger = passengerData.merge(ticketprices, on="TicketType")
merging_passenger.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            9         1       3
# 2           17         0       3
# 3           25         0       3
# 4           33         1       3
# 5           41         0       3
# 6           49         0       3
# 7           57         1       2
# 8           65         0       1
# 9           73         0       2
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 2                               Rice, Master. Eugene    male   2.0
# 3                      Palsson, Miss. Torborg Danira  female   8.0
# 4                           Glynn, Miss. Mary Agatha  female   NaN
# 5     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0
# 6                                Samaan, Mr. Youssef    male   NaN
# ...

# %%
old_pass = merging_passenger.Age.max()
merging_passenger.loc[merging_passenger.Age == old_pass,'Name']
# Out:
# 747    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (12,4), dpi = 200)
sns.scatterplot(x='Age', y='Fare', data = merging_passenger)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
merging_passenger.Fare.nunique()
# Out:
# 8

# %%
sns.scatterplot('Age', 'Fare', data = merging_passenger, hue = 'Sex')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
Female_age = merging_passenger[merging_passenger.Sex =='female']

# %%
Female_age
# Out:
#      PassengerId  Survived  Pclass  \
# 1              9         1       3
# 3             25         0       3
# 4             33         1       3
# 5             41         0       3
# 7             57         1       2
# ..           ...       ...     ...
# 886          856         1       3
# 887          864         0       3
# 888          872         1       1
# 889          880         1       1
# 890          888         1       1
#
#                                                   Name     Sex   Age  \
# 1    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 3                        Palsson, Miss. Torborg Danira  female   8.0
# 4                             Glynn, Miss. Mary Agatha  female   NaN
# 5       Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0
# 7                                    Rugg, Miss. Emily  female  21.0
# ..                                                 ...     ...   ...
# ...

# %%
merging_passenger[merging_passenger.Age >= 40]
# Out:
#      PassengerId  Survived  Pclass  \
# 5             41         0       3
# 12            97         0       1
# 19           153         0       3
# 20           161         0       3
# 29           233         0       2
# ..           ...       ...     ...
# 858          632         0       3
# 860          648         1       1
# 866          696         0       2
# 888          872         1       1
# 889          880         1       1
#
#                                                  Name     Sex   Age  \
# 5      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0
# 12                          Goldschmidt, Mr. George B    male  71.0
# 19                                   Meo, Mr. Alfonzo    male  55.5
# 20                           Cribb, Mr. John Hatfield    male  44.0
# 29                          Sjostedt, Mr. Ernst Adolf    male  59.0
# ..                                                ...     ...   ...
# ...

# %%
merging_passenger[merging_passenger.Age <= 50]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              9         1       3
# 2             17         0       3
# 3             25         0       3
# 5             41         0       3
# ..           ...       ...     ...
# 883          832         1       2
# 885          848         0       3
# 886          856         1       3
# 888          872         1       1
# 890          888         1       1
#
#                                                   Name     Sex    Age  \
# 0                              Braund, Mr. Owen Harris    male  22.00
# 1    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.00
# 2                                 Rice, Master. Eugene    male   2.00
# 3                        Palsson, Miss. Torborg Danira  female   8.00
# 5       Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.00
# ..                                                 ...     ...    ...
# ...

# %%
merging_passenger[(merging_passenger.Sex == "female") & (merging_passenger.Age >= 40) & (merging_passenger.Age <= 50)]
# Out:
#      PassengerId  Survived  Pclass  \
# 5             41         0       3
# 34           273         1       2
# 54           433         1       2
# 55           441         1       2
# 92           737         0       3
# 107          857         1       1
# 132          162         1       2
# 134          178         0       1
# 154          338         1       1
# 188          610         1       1
# 220          866         1       2
# 248          195         1       1
# 267          347         1       2
# 269          363         0       3
# 281          459         1       2
# 312          707         1       2
# 318          755         1       2
# 368          260         1       2
# 373          300         1       1
# 401          524         1       1
# 433          780         1       1
# 453           53         1       1
# 463          133         0       3
# 481          277         0       3
# 494          381         1       1
# ...
